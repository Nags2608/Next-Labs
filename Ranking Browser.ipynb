# %%
import pandas as pd
orders = pd.read_csv("/Users/nags26/Desktop/Next Labs/Data/browser_rankings_data.csv")
orders.head(3)
# Out:
#                                                                                                                                                                                       browser_rankings
# ID Keyword Rank Country Language Date       App ID               Date of Last Description Change Short Description                                                                    Long Description
# 1  browser 2    in      en       2020-12-16 net.fast.web.browser 2020-12-18                      The small, fastest, secure Web Browser, best mo...  One of the smallest, fastest, secure Web Brows...
# 2  browser 3    in      en       2020-12-16 com.android.chrome   2020-12-18                      Fast, simple, and secure. Google Chrome browser...  Google Chrome is a fast, easy to use, and secu...

# %%
# printing all columns of the dataframe
print(orders.columns.tolist())
# Out:
# ['browser_rankings']

# %%
orders.sort_values("browser_rankings")
# Out:
#                                                                                                                                                                              browser_rankings
# 53195  android browser              2   in en 2021-01-27 com.opera.browser   2021-02-27 Fast, safe web browser: free VPN, Ad blocker, Q...  Fast, safe and private, introducing the latest...
# 630    browser                      1   in en 2020-12-22 com.opera.browser   2021-02-27 Fast, safe web browser: free VPN, Ad blocker, Q...  Fast, safe and private, introducing the latest...
# 61085  browser                      5   in en 2021-01-31 com.opera.browser   2021-02-27 Fast, safe web browser: free VPN, Ad blocker, Q...  Fast, safe and private, introducing the latest...
# 90190  browser                      4   in en 2021-02-15 com.opera.browser   2021-02-27 Fast, safe web browser: free VPN, Ad blocker, Q...  Fast, safe and private, introducing the latest...
# ...

# %%
orders["Rank_by_Keyword"] = orders["browser_rankings"].rank(axis=0,ascending=False)

# %%
orders.head()
# Out:
#                                                                                                                                                                                       browser_rankings  \
# ID Keyword Rank Country Language Date       App ID               Date of Last Description Change Short Description                                                                    Long Description
# 1  browser 2    in      en       2020-12-16 net.fast.web.browser 2020-12-18                      The small, fastest, secure Web Browser, best mo...  One of the smallest, fastest, secure Web Brows...
# 2  browser 3    in      en       2020-12-16 com.android.chrome   2020-12-18                      Fast, simple, and secure. Google Chrome browser...  Google Chrome is a fast, easy to use, and secu...
# ...

# %%
orders["Rank_by_Short_description"] = orders["browser_rankings"].rank(axis=0,ascending=False)

# %%
orders.head(10)
# Out:
#                                                                                                                                                                                                 browser_rankings  \
# ID Keyword         Rank Country Language Date       App ID                 Date of Last Description Change Short Description                                                                    Long Description
# 1  browser         2    in      en       2020-12-16 net.fast.web.browser   2020-12-18                      The small, fastest, secure Web Browser, best mo...  One of the smallest, fastest, secure Web Brows...
# 2  browser         3    in      en       2020-12-16 com.android.chrome     2020-12-18                      Fast, simple, and secure. Google Chrome browser...  Google Chrome is a fast, easy to use, and secu...
# ...
